# %% [markdown]
# Python is a high-level, interpreted programming language known for its simplicity and readability.
#
# - Large Standard Library:  Python comes with a comprehensive standard library that provides support for various tasks without the need for additional installations.
#
# - Versatility: Python is a general-purpose language, meaning it can be used for a wide range of applications, including web development, data analysis, artificial intelligence, machine learning, automation, scientific computing, and more.
#
# - Easy to Learn and Read: Python emphasizes readability and simplicity, making it an excellent choice for beginners. Its clean syntax reduces the cost of program maintenance and development.
#
# - Interpretation and Compilation: Python is an interpreted language, which means code is executed line by line, making it easier to debug and test. However, Python can also be compiled into bytecode for improved performance using tools like PyInstaller, Cython, or Nuitka.
#
# - Dynamic Typing: Python uses dynamic typing, meaning you don't need to declare variable types explicitly. This flexibility allows for rapid development and prototyping.
#
# - Community Support: Python has a vast and active community of developers who contribute to its ecosystem by creating libraries, frameworks, and tools. This community support makes it easy to find solutions to problems, learn new techniques, and collaborate on projects.

# %% [markdown]
# **Variables:**
#
# In Python, a variable is a name that refers to a value. You can think of it as a container that holds data. Unlike some other languages, Python doesn't require you to explicitly declare the type of a variable before using it. You simply assign a value to a variable using the equals sign '='.
#
#
#         var_name = value

# %%
name = 'Ekta'

# %%
name
# Out:
# 'Ekta'

# %%
name
# Out:
# 'Ekta'

# %%
name = "Ekta"
name
# Out:
# 'Ekta'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Best practices:**
#
# Use descriptive names: Choose meaningful and descriptive names for variables that accurately represent their purpose or content. Avoid single-letter variable names (except for simple loop counters) and abbreviations that may not be immediately clear to others.

# %%
# Good
total_sales = 1000
user_name = "John Doe"

# Avoid
ts = 1000
un = "John"

# %% [markdown]
# Follow naming conventions: Adhere to Python's naming conventions, such as using lowercase letters with underscores for variable names (snake_case). This convention improves readability and consistency with built-in functions and standard libraries.

# %%
name_1 ='Ekta'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Numeric Types:**
#
# - int: Represents integer values, e.g., 5, 100, -3.
# - float: Represents floating-point numbers (decimals), e.g., 3.14, -2.7, 0.001.
# - complex: Represents complex numbers with real and imaginary parts, e.g., 2 + 3j, -1 - 1j.
#
# **String Types:**
#
# - str: Represents strings, or sequences of characters, e.g., "hello", "123".
#
# **Boolean Type:**
#
# - bool: Represents boolean values, which can be either True or False.

# %%
# int
age = 25
print(age)
type(age)
# Out:
# 25
# int

# %%
age
# Out:
# 25

# %%
# float
height = 5.9
print(height)
type(height)
# Out:
# 5.9
# float

# %%
age = 25.0
print(age)
type(age)
# Out:
# 25.0
# float

# %%
age = '25.0'
print(age)
type(age)
# Out:
# 25.0
# str

# %% [markdown]
# They are sequences of characters enclosed within single quotes `(')`, double quotes` (")`, triple single quotes `(''')`, or triple double quotes` (""")`

# %%
# string
message = "Hello, World!123"
print(message)
type(message)
# Out:
# Hello, World!123
# str

# %%
# bool
is_active = True
print(is_active)
type(is_active)
# Out:
# True
# bool

# %%
age
height
message
is_active
# Out:
# True

# %%
age, height, message, is_active
# Out:
# ('25.0', 5.9, 'Hello, World!123', True)

# %%
print(age)
print(height)
print(message)
is_active
# Out:
# 25.0
# 5.9
# Hello, World!123
# True

# %%
# Multiple variable and Multiple assignment

a, b, c = 12, 3.14, True
a
# Out:
# 12

# %%
b
# Out:
# 3.14

# %%
c
# Out:
# True

# %%
name, age, city = "Alice", 25, "New York"
print(name)
print(age)
print(city)
# Out:
# Alice
# 25
# New York

# %%
age
city
# Out:
# 'New York'

# %%
# Multiple variable and Same assignment

x = y = z = 10
print(x, y, z)
# Out:
# 10 10 10

# %%
# Swao Values
num1 = 10
num2 = 100

print(num1,num2)
# Out:
# 10 100

# %%
num3 = num1
num1 = num2
num2 = num3
print(num1, num2)
# Out:
# 100 10

# %%
num1, num2 = num2, num1

# %%
num1, num2
# Out:
# (10, 100)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Python supports various types of operators, which are symbols used to perform operations on variables and values.
#
# **Arithmetic Operators:**
#
# Arithmetic operators are used to perform mathematical operations on numerical values.
#
#     Addition +
#     Subtraction -
#     Multiplication *
#     Division /
#     Floor Division // (returns the integer part of the quotient)
#     Modulus % (returns the remainder of the division)
#     Exponentiation ** (raises a number to a power)

# %%
a = 10
b = 3

c = a + b
c
# Out:
# 13

# %%
c
# Out:
# 13

# %%
c
# Out:
# 13

# %%
print(a - b)
# Out:
# 7

# %%
2.14 - 2
# Out:
# 0.14000000000000012

# %%
print(a * b)
# Out:
# 30

# %%
print(a / b)
# Out:
# 3.3333333333333335

# %%
print(a // b)
# Out:
# 3

# %%
print(a % b)
# Out:
# 1

# %%
2 ** 2 # base ** power
# Out:
# 4

# %%
2**4
# Out:
# 16

# %%
8** 3
# Out:
# 512

# %%
10 + 12 - 13 * 4
# Out:
# -30

# %% [markdown]
# BODMAS
#
#     Brackets (Parentheses in PEMDAS)
#     Orders (Exponents in PEMDAS, such as powers and roots)
#     Division
#     Multiplication
#     Addition
#     Subtraction

# %%
10 + (12 - 13) * 4
# Out:
# 6

# %% [markdown]
# Formula area of circle = pi * r square
#
# pi = 3.14
# r = 4

# %%
pi=3.14
r=4
circle=pi*r
print(circle)
# Out:
# 12.56

# %% [markdown]
# # Calculate the simple interest
#
#  simple_interest = p * n * r /100
#
#  p = 10000
# n =  5
# r = 5

# %%
p = 10000
n =  5
r = 5
simple_interest = p * n * r /100
print(simple_interest)
# Out:
# 2500.0

# %%
r = input()
r
# Out:
# dfvn dvfkd
# 'dfvn dvfkd'

# %% [markdown]
# **Runtime Input():**
#
# In Python, the input() function is used to take input from the user via the console. It waits for the user to type something and press Enter. The text entered by the user is treated as a string and returned by the input() function.
#
#
#     variable = input(prompt)
#
#     prompt (optional): This is the message displayed to the user before waiting for input. It's a string that serves as a prompt to inform the user what kind of input is expected.

# %%
var = input("Enter a number") # default input in str value
# Out:
# Enter a numbervvn

# %%
type(var)
# Out:
# str

# %%
p = 10000
n =  5
r = input('Enter the rate of interest: ')
simple_interest = p * n * r /100
print(simple_interest)
# Out:
# Enter the rate of interest: 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-655830971.py in <cell line: 0>()
#       2 n =  5
#       3 r = input('Enter the rate of interest: ')
# ----> 4 simple_interest = p * n * r /100
#       5 print(simple_interest)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num1 = 10
num2 = 14.5
num3 = num1 + num2
num3
# Out:
# 24.5

# %%
num1 = 11.1
num2 = 14.5
num3 = num1 + num2
num3
# Out:
# 25.6

# %%
num1 = 11.1
num2 = 14
num3 = num1 + num2
num3
# Out:
# 25.1

# %%
num1 = 11.1
num2 = '14'
num3 = num1 + num2
num3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1394937233.py in <cell line: 0>()
#       1 num1 = 11.1
#       2 num2 = '14'
# ----> 3 num3 = num1 + num2
#       4 num3
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
num1 = 11.1
num2 = '14'
num3 = num1 + int(num2)
num3
# Out:
# 25.1

# %%
p = 10000
n =  5
r = int(input('Enter the rate of interest: '))
simple_interest = p * n * r /100
print(simple_interest)
# Out:
# Enter the rate of interest: 6.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1826152436.py in <cell line: 0>()
#       1 p = 10000
#       2 n =  5
# ----> 3 r = int(input('Enter the rate of interest: '))
#       4 simple_interest = p * n * r /100
#       5 print(simple_interest)
#
# ValueError: invalid literal for int() with base 10: '6.1'

# %%
p = 10000
n =  5
r = float(input('Enter the rate of interest: '))
simple_interest = p * n * r /100
print(simple_interest)
# Out:
# Enter the rate of interest: 7.1
# 3550.0

# %%
num1 = '11'
num2 = '11'

num3 = int(num1) + int(num2)
num3
# Out:
# 22

# %%
num1 = '11'
num2 = '11'

num3 = num1 + num2
num3
# Out:
# '1111'

# %%
a, b
# Out:
# (10, 3)

# %%
a > b
# Out:
# True

# %%
a == b # equals to
# Out:
# False

# %%
a != b # not equal
# Out:
# True

# %%
a / b
# Out:
# 3.3333333333333335

# %%
a % b
# Out:
# 1

# %%
25 % 2
# Out:
# 1

# %%
144 % 3
# Out:
# 0

# %%
20 % 3
# Out:
# 2

# %% [markdown]
# Assignment Operators:
#
# Assignment operators are used to assign values to variables.
#
#     Assignment =
#     Add and assign +=
#     Subtract and assign -=
#     Multiply and assign *=
#     Divide and assign /=
#     Floor divide and assign //=
#     Modulus and assign %=
#     Exponentiate and assign **=

# %%
a
# Out:
# 10

# %%
b
# Out:
# 3

# %%
a += b # a = a + b
a
# Out:
# 13

# %%
b
# Out:
# 3

# %% [markdown]
# Assignment Operators:
#
# Assignment operators are used to assign values to variables.
#
#     Assignment =
#     Add and assign +=
#     Subtract and assign -=
#     Multiply and assign *=
#     Divide and assign /=
#     Floor divide and assign //=
#     Modulus and assign %=
#     Exponentiate and assign **=

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a += b # a = a + b
a
# Out:
# 16

# %%
b
# Out:
# 3

# %%
a -= b # a = a - b
a
# Out:
# 13

# %%
a *= b
a
# Out:
# 39

# %%
a /= b
a
# Out:
# 13.0

# %%
a %= b
a
# Out:
# 1.0

# %% [markdown]
# 1. Python code to calculate the square root of the given number(run time variable)

# %%
# take input from user
num = float(input("Enter a number: "))

# calculate square root without inbuilt function
sqrt_num = num ** 0.5

print("The square root of", num, "is", sqrt_num)
# Out:
# Enter a number: 4
# The square root of 4.0 is 2.0

# %% [markdown]
# 2. Take two inputs from user and check whether they are equal or not.

# %%
# take two inputs from user
a = input("Enter first value: ")
b = input("Enter second value: ")

a == b
# Out:
# Enter first value: 5
# Enter second value: 5
# True

# %% [markdown]
# 3. Take an single digit integer input from the user (3), print an output for (3+(33))

# %%
# take single digit input from user
n = int(input("Enter a single digit number: "))

# form number 33 using the digit
double_digit = n + (n)  # example: '3' + '3' -> '33' -> int(33)

# calculate expression
result = n + double_digit

print("Result:", result)
# Out:
# Enter a single digit number: 3
# Result: 9

# %% [markdown]
# 4. Write Python code to get a runtime variable as float and display as integer
#                    input: float number
#                    output: int number

# %%
# take float input
num = float(input("Enter a float number: "))

# convert to integer
int_num = int(num)

# display result
print("Integer value:", int_num)
# Out:
# Enter a float number: 3.14
# Integer value: 3

# %% [markdown]
# 5. Python Program to Convert Celsius To Fahrenheit
# #####  celsius * 1.8 = fahrenheit - 32

# %%
# take temperature in Celsius from user
celsius = float(input("Enter temperature in Celsius: "))

# convert to Fahrenheit
fahrenheit = (celsius * 1.8) + 32

# display result
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 27
# Temperature in Fahrenheit: 80.6

# %% [markdown]
# 6. Python code for the given number of days, find how many weeks and how many days are left
# ### eg. input = 15 days, # weeks =  2, # days left = 1

# %%
# take input from user
days = int(input("Enter number of days: "))

# calculate weeks and remaining days
weeks = days // 7
days_left = days % 7

# display result
print("Weeks:", weeks)
print("Days left:", days_left)
# Out:
# Enter number of days: 15
# Weeks: 2
# Days left: 1
